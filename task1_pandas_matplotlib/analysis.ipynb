# %%
print("Task 1: Pandas and Matplotlib - Started")
# Out:
# Task 1: Pandas and Matplotlib - Started

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_csv("data/employees.csv")

df
# Out:
#     Name  Age  Salary  Experience
# 0   Amit   25   30000           1
# 1   Neha   28   42000           3
# 2  Rahul   35   60000           7
# 3  Pooja   32   52000           5
# 4  Ankit   40   75000          12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Age         5 non-null      int64
#  2   Salary      5 non-null      int64
#  3   Experience  5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 292.0+ bytes

# %%
df.describe()
# Out:
#             Age        Salary  Experience
# count   5.00000      5.000000    5.000000
# mean   32.00000  51800.000000    5.600000
# std     5.87367  17152.259326    4.219005
# min    25.00000  30000.000000    1.000000
# 25%    28.00000  42000.000000    3.000000
# 50%    32.00000  52000.000000    5.000000
# 75%    35.00000  60000.000000    7.000000
# max    40.00000  75000.000000   12.000000

# %%
average_salary = df["Salary"].mean()
average_salary
# Out:
# np.float64(51800.0)

# %%
average_age = df["Age"].mean()
average_age
# Out:
# np.float64(32.0)

# %%
plt.figure(figsize=(8, 5))
plt.bar(df["Name"], df["Salary"])
plt.xlabel("Employee Name")
plt.ylabel("Salary")
plt.title("Salary of Employees")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.bar(df["Name"], df["Salary"])
plt.xlabel("Employee Name")
plt.ylabel("Salary")
plt.title("Salary of Employees")
plt.savefig("plots/salary_bar_chart.png")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df["Experience"], df["Salary"])
plt.xlabel("Experience (Years)")
plt.ylabel("Salary")
plt.title("Experience vs Salary")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df["Experience"], df["Salary"])
plt.xlabel("Experience (Years)")
plt.ylabel("Salary")
plt.title("Experience vs Salary")
plt.savefig("plots/experience_vs_salary_scatter.png")
plt.show()

# %%
import seaborn as sns

# %%
correlation_matrix = df[["Age", "Salary", "Experience"]].corr()
correlation_matrix
# Out:
#                  Age    Salary  Experience
# Age         1.000000  0.997551    0.988659
# Salary      0.997551  1.000000    0.986659
# Experience  0.988659  0.986659    1.000000

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.savefig("plots/correlation_heatmap.png")
plt.show()
